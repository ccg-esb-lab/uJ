# %%
import math,os,array
import matplotlib.pyplot as plt

# %% [markdown]
# # Sine 1 hr   20180123

# %%
signal_in_frames=True
if(signal_in_frames):
    frame2min=5
    min2frame=1
else:
    frame2min=1
    min2frame=5

    
    
dir_one="data_eclipse_002"
dir_two="data_eclipse_003"
notdir="x"

sineStart=300*min2frame
last_frame=300*min2frame
second_last_frame=540*min2frame
sine_period=1
sine_period_min=sine_period*60
pi=math.pi

path_to_data="/home/charly/Lab/Projects/uJ/uJ_data/HT-Sines/20180123_Charly_HT13_Sine_1hrs/"
filename=os.path.join(path_to_data,"HT13_sine_signal_1hr.txt")
print(filename)
file=open(filename,"w+")

file.write("#frame\tLB\tCaz\tAmp\tdir\n")

fig, ax = plt.subplots(ncols=1, figsize=(16, 4.5))

time=[]
amps=[]
cazs=[]
fr=1
dirF=dir_one
for i in range(1,sineStart):
    file.write("%d\t1\t%f\t%f\t%s\n" % (fr,0,0,dirF))
    time.append(fr),amps.append(0),cazs.append(0)
    fr+=1

fr=fr-sineStart
print(fr)
for i in range(sineStart,last_frame+1):
    print(i)    
    if((fr)%(sine_period_min/frame2min)==0):
        plt.axvline(i)
    
    amp=(math.sin(fr*frame2min*2*pi/sine_period_min)+1)/2
    caz=1-amp
    
    file.write("%d\t%d\t%f\t%f\t%s\n" % ((fr+sineStart),0,amp,caz,dirF))
    time.append(i),amps.append(amp),cazs.append(caz)
    fr+=1

#fig, ax = plt.subplots(ncols=1, figsize=(16, 4.5))
plt.axvline(i,color='r')
a=i

print(fr)
dirF=dir_two
flag=True
second_end=fr+second_last_frame

for i in range(fr,second_end):
    
    amp=(math.sin(i*frame2min*2*pi/sine_period_min)+1)/2
    if(fr%(sine_period_min/frame2min)==0):
        plt.axvline(i+sineStart)
#     if(fr%(sine_period_min/frame2min)==320/frame2min and flag):
#         b=i+sineStart
#         plt.axvline(b,color='g')
#         flag=False
#         dirF=dir_two
   
    caz=1-amp
    
    file.write("%d\t%d\t%f\t%f\t%s\n" % ((fr+sineStart),0,amp,caz,dirF))
    time.append(i+sineStart),amps.append(amp),cazs.append(caz)
    fr+=1
    
    
    
file.close()


plt.plot(time,amps)
#print("Time not captured:\n%d min \n%d frames\n%d" %((b-a)*frame2min, (b-a)/min2frame ,fr+sineStart ))
print(fr,fr+sineStart)
plt.show()
# Out:
# /home/charly/Lab/Projects/uJ/uJ_data/HT-Sines/20180123_Charly_HT13_Sine_1hrs/HT13_sine_signal_1hr.txt
# 0
# 300
# 1
# 541 841

# %% [markdown]
# # Sine 1 hr  20180303

# %%
frame2min=5
sineStart=67
last_frame=255
sine_period=1
sine_period_min=sine_period*60
pi=math.pi
dir_one="data_eclipse"
path_to_data="/home/charly/Lab/Projects/uJ/uJ_data/HT-Sines/20180303_Charly_HT13_Sine_1hrs/"
filename=os.path.join(path_to_data,"HT13_sine_signal_1hr.txt")
print(filename)
file=open(filename,"w")

file.write("#frame\tLB\tCaz\tAmp\tdir\n")

fig, ax = plt.subplots(ncols=1, figsize=(16, 4.5))

time=[]
amps=[]
cazs=[]
fr=1
dirF=dir_one
for i in range(1,sineStart):
    file.write("%d\t1\t%f\t%f\t%s\n" % (fr,0,0,dirF))
    time.append(fr),amps.append(0),cazs.append(0)
    fr+=1

fr=fr-sineStart
print(fr)
for i in range(sineStart,last_frame+1):
  #  print(i)    
    if((fr)%(sine_period_min/frame2min)==0):
        plt.axvline(i)
    
    amp=(math.sin(fr*frame2min*2*pi/sine_period_min)+1)/2
    caz=1-amp
    
    file.write("%d\t%d\t%f\t%f\t%s\n" % ((fr+sineStart),0,amp,caz,dirF))
    time.append(i),amps.append(amp),cazs.append(caz)
    fr+=1

    
    
    

file.close()

plt.plot(time,amps)
#print("Time not captured:\n%d min \n%d frames\n%d" %((b-a)*frame2min, (b-a)/min2frame ,fr+sineStart ))
print(fr,fr+sineStart)
plt.show()
# Out:
# /home/charly/Lab/Projects/uJ/uJ_data/HT-Sines/20180303_Charly_HT13_Sine_1hrs/HT13_sine_signal_1hr.txt
# 0
# 189 256

# %% [markdown]
# # Sine 4 hr

# %%
path_to_data="/home/charly/Lab/Projects/uJ/uJ_data/HT-Sines/20180307_Charly_HT13_Sine_4hrs/"
filename=os.path.join(path_to_data,"HT13_sine_signal_4hr.txt")


signal_in_frames=True
if(signal_in_frames):
    frame2min=5
    min2frame=1
else:
    frame2min=1
    min2frame=5

    
    
dir_one="data_eclipse_001"
dir_two="data_eclipse_002"
notdir="x"

sineStart=117*min2frame
last_frame=219*min2frame
second_last_frame=186*min2frame
sine_period=4
sine_period_min=sine_period*60
pi=math.pi


print(filename)
file=open(filename,"w")

file.write("#frame\tLB\tCaz\tAmp\tdir\n")

fig, ax = plt.subplots(ncols=1, figsize=(16, 4.5))

time=[]
amps=[]
cazs=[]
fr=1
dirF=dir_one
for i in range(1,sineStart):
    file.write("%d\t1\t%f\t%f\t%s\n" % (fr,0,0,dirF))
    time.append(fr),amps.append(0),cazs.append(0)
    fr+=1

fr=fr-sineStart
print(fr)
for i in range(sineStart,last_frame):
        
    if((fr)%(sine_period_min/frame2min)==0):
        plt.axvline(i)
    
    amp=(math.sin(fr*frame2min*2*pi/sine_period_min)+1)/2
    caz=1-amp
    
    file.write("%d\t%d\t%f\t%f\t%s\n" % ((fr+sineStart),0,amp,caz,dirF))
    time.append(i),amps.append(amp),cazs.append(caz)
    fr+=1

#fig, ax = plt.subplots(ncols=1, figsize=(16, 4.5))
plt.axvline(i,color='r')
a=i

print(fr)
dirF=dir_two

second_end=second_last_frame
fr=0
for i in range(fr,second_end):
    
    amp=(math.sin(i*frame2min*2*pi/sine_period_min)+1)/2
    if(fr%(sine_period_min/frame2min)==0):
        plt.axvline(i+sineStart)
   
   
    caz=1-amp
    
    file.write("%d\t%d\t%f\t%f\t%s\n" % ((fr+a+2),0,amp,caz,dirF))
    time.append(i+a),amps.append(amp),cazs.append(caz)
    fr+=1
    
    


file.close()
plt.plot(time,amps)
#print("Time not captured:\n%d min \n%d frames\n%d" %((b-a)*frame2min, (b-a)/min2frame ,fr+sineStart ))
plt.show()
# Out:
# /home/charly/Lab/Projects/uJ/uJ_data/HT-Sines/20180307_Charly_HT13_Sine_4hrs/HT13_sine_signal_4hr.txt
# 0
# 102

# %% [markdown]
# # Sine 8 hr 20180404

# %%
signal_in_frames=True
if(signal_in_frames):
    frame2min=5
    min2frame=1
else:
    frame2min=1
    min2frame=5

    
path_to_data="/home/charly/Lab/Projects/uJ/uJ_data/HT-Sines/20180404_Charly_HT13_Sine_8hrs/"
filename=os.path.join(path_to_data,"HT13_sine_signal_8hr.txt")
    
dir_one="data_eclipse"

sineStart=41*min2frame
last_frame=203*min2frame
sine_period=8
sine_period_min=sine_period*60
pi=math.pi


print(filename)
file=open(filename,"w")

file.write("#frame\tLB\tCaz\tAmp\tdir\n")

fig, ax = plt.subplots(ncols=1, figsize=(16, 4.5))

time=[]
amps=[]
cazs=[]
fr=1
dirF=dir_one
for i in range(1,sineStart):
    file.write("%d\t1\t%f\t%f\t%s\n" % (fr,0,0,dirF))
    time.append(fr),amps.append(0),cazs.append(0)
    fr+=1

fr=fr-sineStart
print(fr)
for i in range(sineStart,last_frame+1):
        
    if((fr)%(sine_period_min/frame2min)==0):
        plt.axvline(i)
    
    amp=(math.sin(fr*frame2min*2*pi/sine_period_min)+1)/2
    caz=1-amp
    
    file.write("%d\t%d\t%f\t%f\t%s\n" % ((fr+sineStart),0,amp,caz,dirF))
    time.append(i),amps.append(amp),cazs.append(caz)
    fr+=1

#fig, ax = plt.subplots(ncols=1, figsize=(16, 4.5))
plt.axvline(i,color='r')
    
    


file.close()
plt.plot(time,amps)
#print("Time not captured:\n%d min \n%d frames\n%d" %((b-a)*frame2min, (b-a)/min2frame ,fr+sineStart ))
plt.show()
# Out:
# /home/charly/Lab/Projects/uJ/uJ_data/HT-Sines/20180404_Charly_HT13_Sine_8hrs/HT13_sine_signal_8hr.txt
# 0

# %% [markdown]
# # Sine 8 hr 20180410 rep

# %%
signal_in_frames=True
if(signal_in_frames):
    frame2min=5
    min2frame=1
else:
    frame2min=1
    min2frame=5




sine_period_min=sine_period*60
pi=math.pi
path_to_data="/home/charly/Lab/Projects/uJ/uJ_data/HT-Sines/20180410_Charly_HT13_Sine_8hrs/"
filename=os.path.join(path_to_data,"HT13_sine_signal_8hr.txt")

    
dir_one="data_eclipse"

sineStart=20*min2frame
last_frame=404*min2frame
sine_period=8
sine_period_min=sine_period*60
pi=math.pi


print(filename)
file=open(filename,"w")

file.write("#frame\tLB\tCaz\tAmp\tdir\n")

fig, ax = plt.subplots(ncols=1, figsize=(16, 4.5))

time=[]
amps=[]
cazs=[]
fr=1
dirF=dir_one
for i in range(1,sineStart):
    file.write("%d\t1\t%f\t%f\t%s\n" % (fr,0,0,dirF))
    time.append(fr),amps.append(0),cazs.append(0)
    fr+=1

fr=fr-sineStart
print(fr)
for i in range(sineStart,last_frame+1):
        
    if((fr)%(sine_period_min/frame2min)==0):
        plt.axvline(i)
        print(fr+sineStart,i)
    amp=(math.sin(fr*frame2min*2*pi/sine_period_min)+1)/2
    caz=1-amp
    
    file.write("%d\t%d\t%f\t%f\t%s\n" % ((fr+sineStart),0,amp,caz,dirF))
    time.append(i),amps.append(amp),cazs.append(caz)
    fr+=1

#fig, ax = plt.subplots(ncols=1, figsize=(16, 4.5))
plt.axvline(i,color='r')
    
    


file.close()
plt.plot(time,amps)
#print("Time not captured:\n%d min \n%d frames\n%d" %((b-a)*frame2min, (b-a)/min2frame ,fr+sineStart ))
plt.show()
# Out:
# /home/charly/Lab/Projects/uJ/uJ_data/HT-Sines/20180410_Charly_HT13_Sine_8hrs/HT13_sine_signal_8hr.txt
# 0
# 20 20
# 116 116
# 212 212
# 308 308
# 404 404

# %% [markdown]
# # Sine 8 hr 20180422  rep2

# %%
signal_in_frames=True
if(signal_in_frames):
    frame2min=5
    min2frame=1
else:
    frame2min=1
    min2frame=5

    
    
dir_one="data_eclipse_002"
dir_two="data_eclipse_003"
notdir="x"

sineStart=32*min2frame
last_frame=158*min2frame
second_last_frame=577*min2frame
sine_period=8
sine_period_min=sine_period*60
pi=math.pi

path_to_data="/home/charly/Lab/Projects/uJ/uJ_data/HT-Sines/20180422_Charly_HT13_Sine_8hrs/"
filename=os.path.join(path_to_data,"HT13_sine_signal_8hr.txt")
print(filename)
file=open(filename,"w+")

file.write("#frame\tLB\tCaz\tAmp\tdir\n")

fig, ax = plt.subplots(ncols=1, figsize=(16, 4.5))

time=[]
amps=[]
cazs=[]
fr=1
dirF=dir_one
for i in range(1,sineStart):
    file.write("%d\t1\t%f\t%f\t%s\n" % (fr,0,0,dirF))
    time.append(fr),amps.append(0),cazs.append(0)
    fr+=1

fr=fr-sineStart
print(fr)
for i in range(sineStart,last_frame+1):
        
    if((fr)%(sine_period_min/frame2min)==0):
        plt.axvline(i)
    
    amp=(math.sin(fr*frame2min*2*pi/sine_period_min)+1)/2
    caz=1-amp
    
    file.write("%d\t%d\t%f\t%f\t%s\n" % ((fr+sineStart),0,amp,caz,dirF))
    time.append(i),amps.append(amp),cazs.append(caz)
    fr+=1

#fig, ax = plt.subplots(ncols=1, figsize=(16, 4.5))
plt.axvline(i,color='r')
a=i

print(fr)
dirF=notdir
flag=True
second_end=fr+second_last_frame+sineStart

for i in range(fr,second_end+1):
    
    amp=(math.sin(i*frame2min*2*pi/sine_period_min)+1)/2
    if(fr%(sine_period_min/frame2min)==0):
        plt.axvline(i+sineStart)
    if(fr%(sine_period_min/frame2min)==320/frame2min and flag):
        b=i+sineStart
        plt.axvline(b,color='g')
        flag=False
        dirF=dir_two
   
    caz=1-amp
    
    file.write("%d\t%d\t%f\t%f\t%s\n" % ((fr+sineStart),0,amp,caz,dirF))
    time.append(i+sineStart),amps.append(amp),cazs.append(caz)
    fr+=1
    
    
    
lost_in_frames=int((b-a)/min2frame)

for i in range(fr,lost_in_frames+1):
    
    amp=(math.sin(i*frame2min*2*pi/sine_period_min)+1)/2
    if(fr%(sine_period_min/frame2min)==0):
        plt.axvline(i+sineStart)
    caz=1-amp
    
    file.write("%d\t%d\t%f\t%f\t%s\n" % ((fr+sineStart),0,amp,caz,dirF))
    time.append(i+sineStart),amps.append(amp),cazs.append(caz)
    fr+=1



file.close()
plt.plot(time,amps)
print("Time not captured:\n%d min \n%d frames\n%d" %((b-a)*frame2min, (b-a)/min2frame ,fr+sineStart ))
plt.show()
# Out:
# /home/charly/Lab/Projects/uJ/uJ_data/HT-Sines/20180422_Charly_HT13_Sine_8hrs/HT13_sine_signal_8hr.txt
# 0
# 127
# Time not captured:
# 170 min
# 34 frames
# 769

# %% [markdown]
# # Sine 2 hr

# %%
signal_in_frames=True
if(signal_in_frames):
    frame2min=5
    min2frame=1
else:
    frame2min=1
    min2frame=5

    
    
dir_one="data_eclipse_000"
dir_two="data_eclipse_001"
notdir="x"

sineStart=24*min2frame
last_frame=116*min2frame
second_last_frame=67*min2frame
sine_period=2
sine_period_min=sine_period*60
pi=math.pi

path_to_data="/home/charly/Lab/Projects/uJ/uJ_data/HT-Sines/20180502_Charly_HT13_Sine_2hrs/"
filename=os.path.join(path_to_data,"HT13_sine_signal_2hr.txt")
print(filename)
file=open(filename,"w")

file.write("#frame\tLB\tCaz\tAmp\tdir\n")

fig, ax = plt.subplots(ncols=1, figsize=(16, 4.5))

time=[]
amps=[]
cazs=[]
fr=1
dirF=dir_one
for i in range(1,sineStart):
    file.write("%d\t1\t%f\t%f\t%s\n" % (fr,0,0,dirF))
    time.append(fr),amps.append(0),cazs.append(0)
    fr+=1
    

    
print(fr)
    
fr=fr-sineStart

for i in range(sineStart,last_frame+1):
    
    if((fr)%(sine_period_min/frame2min)==0):
        plt.axvline(i)
    
    amp=(math.sin(fr*frame2min*2*pi/sine_period_min)+1)/2
    caz=1-amp
    
    file.write("%d\t%d\t%f\t%f\t%s\n" % ((fr+sineStart),0,amp,caz,dirF))
    time.append(i),amps.append(amp),cazs.append(caz)
    fr+=1

#fig, ax = plt.subplots(ncols=1, figsize=(16, 4.5))
plt.axvline(i,color='r')
a=i
b='x'
print(fr)
dirF=notdir
flag=0
second_end=fr+second_last_frame-1

for i in range(fr,second_end):
    amp=(math.sin(i*frame2min*2*pi/sine_period_min)+1)/2
    if(fr%(sine_period_min/frame2min)==0):
        plt.axvline(i+sineStart)
    if(fr%(sine_period_min/frame2min)==0/frame2min and flag<=1):
        b=i+sineStart
        plt.axvline(b,color='g')
        if flag==1 :
            dirF=dir_two
        flag=flag+1
        
    caz=1-amp
    
    file.write("%d\t%d\t%f\t%f\t%s\n" % ((fr+sineStart),0,amp,caz,dirF))
    time.append(i+sineStart),amps.append(amp),cazs.append(caz)
    fr+=1
    

lost_in_frames=int((b-a)/min2frame)

for i in range(fr,fr+lost_in_frames):
    
    amp=(math.sin(i*frame2min*2*pi/sine_period_min)+1)/2
    if(fr%(sine_period_min/frame2min)==0):
        plt.axvline(i+sineStart)
    caz=1-amp
    
    file.write("%d\t%d\t%f\t%f\t%s\n" % ((fr+sineStart),0,amp,caz,dirF))
    time.append(i+sineStart),amps.append(amp),cazs.append(caz)
    fr+=1



file.close()
plt.plot(time,amps)
print("Time not captured:\n%d min \n%d frames\n%d" %((b-a)*frame2min, (b-a)/min2frame ,fr+sineStart ))
plt.show()
##correct this signal, second start on 120 not 60
##re-run everything
# Out:
# /home/charly/Lab/Projects/uJ/uJ_data/HT-Sines/20180502_Charly_HT13_Sine_2hrs/HT13_sine_signal_2hr.txt
# 24
# 93
# Time not captured:
# 140 min
# 28 frames
# 211
