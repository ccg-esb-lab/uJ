# %%
import sys
import os
import numpy as np
from matplotlib import pyplot as plt
import matplotlib as mpl
import matplotlib.patches as patches
from shapely.geometry import Point
from shapely.geometry import MultiPoint
from shapely.geometry import MultiPolygon
from shapely.geometry import Polygon
from shapely.geometry import box
from descartes.patch import PolygonPatch
import ipywidgets as widgets
import ipywidgets.widgets.interaction
#from ipywidgets import interactive, fixed
from ipywidgets import *
import random
import pandas as pd

import re

from shapely import geometry
import pickle
import time

from ipyparallel import Client

from shapely import affinity
from shapely.geometry import LineString
import warnings
warnings.simplefilter('ignore', np.RankWarning)
import gc
gc.enable()

# %%
#os.chdir('/home/charly/Lab/Projects/uJ/local/experiments/HT-AMP/')
#os.chdir('/home/esb/Projects/uJ/local/experiments/HT-Sine2hr/')

# %%
pwd()
# Out:
# '/home/esb/Projects/uJ/local/experiments/HT-AMP'

# %%
#sys.path.insert(0, '/Users/ESB/RPM_SYNC/RPM_Work/uJ_master/current/uJ_src/python/')
#sys.path.insert(0, '/home/esb/Projects/uJ/uJ_master/current/uJ_src/python/')
#sys.path.insert(0, '/Users/ESB/SYNC_RPM/RPM_Work/uJ_master/current/uJ_src/python/')
#sys.path.insert(0, '/home/charly/Lab/Projects/uJ/uJ_master/current/uJ_src/python/')
sys.path.insert(0, '/home/charly/Lab/Projects/uJ/local/current/uJ_src_pHT/python/')
sys.path.insert(0, '/home/esb/Projects/uJ/local/current/uJ_src_pHT/python/')

# %%
from readroi import *
from DataManagers import *
from TrackingFunctions import *
from PlottingFunctions import *
# Out:
# Importing readroi
# DataStructs...loaded!
# DataManagers...loaded!
# TrackingFunctions... loaded!
# PlottingFunctions... loaded!

# %%
# import sys, importlib
# importlib.reload(sys.modules['DataManagers'])
# importlib.reload(sys.modules['TrackingFunctions'])
# from DataManagers import *
# from TrackingFunctions import *

# %% [markdown]
# ## Note
# ### Start a cluster with ipcluster start

# %% [markdown]
# ## Experiment Parameters

# %%
expeLabel="HT-AMP"
rootDir="../../data_sample/HT-AMP/"
trap_list="xy01,xy02,xy03,xy04,xy05,xy06,xy07,xy11,xy12,xy13,xy14,xy15,xy16,xy21".split(",")  
trap_list="xy15,xy15-1".split(",")  


figxlim=640
figylim=512

flims=(figxlim,figylim)

data_type="normData"

#Input files
for trap in trap_list:
    #Input files
    dirNameROIs=rootDir+"data_rois/"+trap+"/DsRed+GFP/"
    #dirNameDATA=rootDir+'data/'+data_type+'/'+trap+"/"
    dirNameDATA=rootDir+'data/'+data_type+'/'+trap+"/"
    
    #Output
    dirNameCELLS=rootDir+'data_cells/'+trap+'/'+data_type+'/'
    if not os.path.exists(dirNameCELLS):
        print("making dir cells...")
        os.makedirs(dirNameCELLS)

    dirNameTRACKEDCELLS=rootDir+'data_cells_tracked/'+trap+'/'+data_type+'/'
    if not os.path.exists(dirNameTRACKEDCELLS):
        print("making dir tracked cells...")
        os.makedirs(dirNameTRACKEDCELLS)



    dirNameTRACKEDCELLS_IMGS=rootDir+'images_cells_tracked/'+trap+'/'+data_type+'/'
    if not os.path.exists(dirNameTRACKEDCELLS_IMGS):
        print("making dir tracked cells imgs ...")
        os.makedirs(dirNameTRACKEDCELLS_IMGS)

    dirNameDATALINEAGES=rootDir+'data/'
    if not os.path.exists(dirNameDATALINEAGES):
        print("making dir lineages...")
        os.makedirs(dirNameDATALINEAGES)
        
    dirNameFIGURES=rootDir+'figures/traked_cells/'+trap+'/'+data_type+'/'
    if not os.path.exists(dirNameFIGURES):
        print("making dir figures...")
        os.makedirs(dirNameFIGURES)
#toFile=False
toFile=True

#toFile=False
toFile=True
frame2min=10
frame_experiment_start=37;
frame_signal_start=int(91-(frame_experiment_start-1)/2)
frame_signal_end=int(127-(frame_experiment_start-1)/2)
frame_experiment_end=int(145-(frame_experiment_start-1)/2)
frame_experiment_end=163

frame_experiment_start=55;
frame_signal_start=91
frame_signal_end=127
frame_experiment_end=127


print("frame_experiment_start: ",frame_experiment_start)
print("frame_signal_start: ",frame_signal_start)
print("frame_signal_end: ",frame_signal_end)
print("frame_experiment_end: ",frame_experiment_end)


t_experiment_start=0
t_signal_start=(frame_signal_start-frame_experiment_start)*frame2min  
t_signal_end=(frame_signal_end-frame_experiment_start)*frame2min
t_experiment_end=(frame_experiment_end-frame_experiment_start)*frame2min

frames=range(int(frame_experiment_start),int(frame_experiment_end+1))

frames_list=[x for x in frames]
times=[(this_frame-frame_experiment_start)*frame2min for this_frame in frames]
times_hour=[(this_frame-frame_experiment_start)*frame2min/60 for this_frame in frames]
#print("\nMinutes:  %s"%times)
#print("\nHours:  [%s,%s]"%(times_hour[0],times_hour[-1]))


print("\nFrames:  %s\t %s->%s hours"%(frames,times_hour[0],times_hour[-1]))
print(len(frames_list))
print("\nFrame list:  %s"%(frames_list))
print("t_experiment_start=%s\t(%sh)"%(t_experiment_start, t_experiment_start/60))
print("t_signal_start=%s\t(%sh)"%(t_signal_start,t_signal_start/60))
print("t_signal_end=%s\t(%sh)"%(t_signal_end, t_signal_end/60))
print("t_experiment_end=%s\t(%sh)"%(t_experiment_end, t_experiment_end/60))


#Prepare file system
dataPath="%sdata/DsRed+GFP/"%rootDir




#if not os.path.exists(figurePathDM) and toFile:
#    os.mkdir(figurePathDM)
# Out:
# frame_experiment_start:  55
# frame_signal_start:  91
# frame_signal_end:  127
# frame_experiment_end:  127
#
# Frames:  range(55, 128)	 0.0->12.0 hours
# 73
#
# Frame list:  [55, 56, 57, 58, 59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 92, 93, 94, 95, 96, 97, 98, 99, 100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 121, 122, 123, 124, 125, 126, 127]
# t_experiment_start=0	(0.0h)
# t_signal_start=360	(6.0h)
# t_signal_end=720	(12.0h)
# t_experiment_end=720	(12.0h)

# %% [markdown]
# ___
# # Create Cells

# %% [markdown]
# ### Load ROIs generated by uJ

# %%
fileROIs=load_rois(dirNameROIs)
dataFiles=load_data_files(dirNameDATA)
numFrames=len(fileROIs)
#print('Loading %s frames'%numFrames)
#meanGFP-750print('Loading %s data files'%len(dataFiles))

fileROIs=fileROIs[0:frame_experiment_end]
dataFiles=dataFiles[0:frame_experiment_end]
#fileROIs=fileROIs[0:5]
#dataFiles=dataFiles[0:5]

numFrames=len(fileROIs)
print('Loading  %s frames'%numFrames)
print('Loading %s data files'%len(dataFiles))

    
   ##### NOTE if path not found check the NAME of your local sync folder
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-f0c00a748348> in <module>()
#       1
# ----> 2 fileROIs=load_rois(dirNameROIs)
#       3 dataFiles=load_data_files(dirNameDATA)
#       4 numFrames=len(fileROIs)
#       5 #print('Loading %s frames'%numFrames)
#
# ~/Projects/uJ/local/current/uJ_src_pHT/python/DataManagers.py in load_rois(dirNameROIs)
#     216     #fileNames=os.listdir(dirNameROIs)
#     217     #filter(lambda k: '.zip' in k, fileNames)
# --> 218     fileNames= list(f for f in os.listdir(dirNameROIs) if f.endswith('.zip'))
#     219     fileNames.sort()
#     220
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../data_sample/HT-AMP/data_rois/xy15-1/DsRed+GFP/'

# %% [markdown]
# ### Process ROIs (parallel version)

# %%
def par_process_rois():
    
    import numpy as np
    
    def get_max_x_angle(poly):
        rangle=0
        angles= list(range(0,185,5))
        (bminx, bminy, bmaxx, bmaxy)=poly.bounds
        xl=bmaxx-bminx
        yl=bmaxy-bminy
        center=Point((xl/2)+bminx,(yl/2)+bminy)

        max_xrange=xl
        for i,angle in enumerate(angles):
            #print(i,angle)
            poly_t=affinity.rotate(poly,angle,center)
            (bminx, bminy, bmaxx, bmaxy)=poly_t.bounds
            xl=bmaxx-bminx

            if(xl>max_xrange):
                max_xrange=xl
                rangle=angle

        return rangle,center


    def get_cell_axis(poly):
      #  t=time.time()
        line=LineString()
        pre_cloud=[]
      #  poly=poly.convex_hull
#         if(poly.geom_type=="Point"):
            
#             poly=poly.buffer(1)
        angle,center=get_max_x_angle(poly)

        poly=affinity.rotate(poly, angle,center )

        ext=poly.exterior.coords

        decs=0

        for i,seed_point in enumerate(ext):
            pre_cloud_i=[]

            seed_point=Point(seed_point)

            i=.5;
            intersection=poly.exterior.intersection(seed_point)
            sphere=seed_point.buffer(i)
            intersection=poly.exterior.intersection(sphere.exterior)
            while(len(list(intersection))>0):
                arc=Point()
                sphere=seed_point.buffer(i)
                intersection=poly.exterior.intersection(sphere.exterior)
                i+=3
                #i+=.5

                if(len(list(intersection))<=1):
                    continue

                arc=poly.intersection(sphere.exterior)

                if(arc.geom_type=="MultiLineString"):

                    for this_geom in arc.geoms:
                        arc_xy=list(this_geom.coords)

                        for pi in arc_xy:
                            pi=Point(pi)
                            pre_cloud_i.append((round(pi.x,decs),round(pi.y,decs)))

                elif(arc.geom_type=="LineString"):
                    for pi in list(arc.coords):
                        pi=Point(pi) 
                        pre_cloud_i.append((round(pi.x,decs),round(pi.y,decs)))


            pre_cloud.append(pre_cloud_i)


        cloud=MultiPoint(pre_cloud[0])

        for line in pre_cloud:

            line=MultiPoint(line)
            cloud=cloud.union(line)

        ###make poly fit to points cloud
        xs=[]
        ys=[]
        for pi in cloud:
            pi=Point(pi)

            xs.append(pi.x)
            ys.append(pi.y)

        pf=np.poly1d(np.polyfit(xs,ys,25))
        xr=np.linspace(np.min(xs),np.max(xs),100)

        line=[]
        for x in xr:
            pi=Point(x,pf(x))
            line.append(pi)

        line=LineString(line)
        linexy=np.array(line)
        linex=linexy[:,0]
        liney=linexy[:,1]

        line=poly.intersection(line)
        liner=affinity.rotate(line,-angle,center)
        if(liner.geom_type=="MultiLineString"):
            line=LineString()
            for this_geom in liner.geoms:
                if(this_geom.length>line.length):
                    line=this_geom
            liner=line



        linexy=np.array(liner)
        linex=linexy[:,0]
        liney=linexy[:,1]

        x=(np.max(xs)-np.min(xs))/2+np.min(xs)
        pi=Point(x,pf(x))


        center=affinity.rotate(pi,-angle,center)
       # t=time.time()-t
       # print(t)

        return liner,center
    
    frame_axis=[]
    frame_centers=[]
    for j,this_roi in enumerate(rois):
        print(j,this_roi)
        this_axis,this_center=get_cell_axis(this_roi)
            
        frame_axis.append(this_axis)
        frame_centers.append(this_center)
    ret=[rois, roiIDs, frame_axis, frame_centers]
    return ret

# %%
trap_list[0:1]
# Out:
# ['xy15']

# %%
re_do_cells=False
re_do_cells=True

trap_cells=[]

#trap_list="xy15".split(",")  #temp no 06



for trap in trap_list[0:1]:
    dirNameROIs=rootDir+"data_rois/"+trap+"/DsRed+GFP/"
    dirNameDATA=rootDir+'data/'+data_type+'/'+trap+"/"
    dirNameCELLS=rootDir+'data_cells/'+trap+'/'+data_type+'/'
    fileROIs=load_rois(dirNameROIs)
    dataFiles=load_data_files(dirNameDATA)
    
    fx=frame_experiment_start-37
    fileROIs=fileROIs[fx:]
    #dataFiles=dataFiles[fx:]
    
    numFrames=len(fileROIs)
    numData=len(dataFiles)
    
    
    print('Loading %s frames'%numFrames)
    print('Loading %s data files'%numData)
    #print('Loading %s data files'%len(dataFiles))

    #fileROIs=fileROIs[0:frame_experiment_end-frame_experiment_start+1]
    #dataFiles=dataFiles[0:frame_experiment_end-frame_experiment_start+1]

    #fileROIs=fileROIs[19:20]
    #dataFiles=dataFiles[19:20]
    
#     fx=frame_experiment_end-frame_experiment_start
#     fileROIs=fileROIs[fx:frame_experiment_end-frame_experiment_start+1]
#     dataFiles=dataFiles[fx:frame_experiment_end-frame_experiment_start+1]
    
    
    
    #print(x)
    #fileROIs=fileROIs[0:2]
    #dataFiles=dataFiles[0:2]

    #numFrames=len(fileROIs)
    #print('Loading  %s frames'%numFrames)
    #print('Loading %s data files'%len(dataFiles))



    if re_do_cells:
        rc = Client()
        dview = rc[:]
        with rc[:].sync_imports(): 
            from shapely.geometry import Point
            from shapely.geometry import LineString
            from shapely import affinity
            from shapely.geometry import MultiPoint


        global cells  # global?
        cells=[]
        for frame, this_file in enumerate(fileROIs):
            [rois,roiIDs]=load_frame('%s%s'%(dirNameROIs,this_file))
            this_data_file="%s%s"%(dirNameDATA,dataFiles[frame])
            
            #rois=[poly.convex_hull for poly in rois]
            
            print("\n(Parallel) Processing %s ROIs from %s"%(len(rois),this_file))


            tic()

            #First scatter rois
            dview.scatter('rois', rois)
            dview.scatter('roiIDs', roiIDs)

            #Asynchronous execution of par_process_rois
            ret=dview.apply_async(par_process_rois)

            #Now gather results
            frame_rois = []
            frame_roiIDs = []
            frame_axis = []
            frame_center = []

            ret_proc=ret.get()
            for i in rc.ids:
                frame_rois.append(ret_proc[i][0])
                frame_roiIDs.append(ret_proc[i][1])
                frame_axis.append(ret_proc[i][2])
                frame_center.append(ret_proc[i][3])

            frame_rois=[y for x in frame_rois for y in x]
            frame_roiIDs=[y for x in frame_roiIDs for y in x]
            frame_axis=[y for x in frame_axis for y in x]
            frame_center=[y for x in frame_center for y in x]

            toc()

            print("Compiling fluorescence from %s"%(dataFiles[frame]))
            this_cells=create_cells(frame,this_data_file, frame_roiIDs, frame_rois, frame_axis, frame_center,frame_experiment_start)
            cells.append(this_cells)

            fileNameCells="%s%s.pkl"%(dirNameCELLS,os.path.splitext(os.path.basename(this_file))[0])    
            save_cells(this_cells, fileNameCells)
    
        trap_cells.append(cells)
    
    else:
        print()
        #max_frames=-1
        cells=load_cells(dirNameCELLS)
        trap_cells.append(cells)
        ##### NOTE   if not working check for changes in your folder names due to sync
# Out:
# Loading 73 frames
# Loading 73 data files
# importing Point from shapely.geometry on engine(s)
# importing LineString from shapely.geometry on engine(s)
# importing affinity from shapely on engine(s)
# importing MultiPoint from shapely.geometry on engine(s)
# /home/esb/.anaconda3/lib/python3.6/site-packages/ipyparallel/client/client.py:459: RuntimeWarning:
#             Controller appears to be listening on localhost, but not on this machine.
#             If this is true, you should specify Client(...,sshserver='you@strix')
#             or instruct your controller to listen on an external IP.
#   RuntimeWarning)
# (Parallel) Processing 503 ROIs from HT-AMP_xy15_055.zip
# Elapsed time: 39.488820 seconds.
# Compiling fluorescence from HT-AMP_xy15_055.txt
# Saving 503 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_055.pkl
#
# (Parallel) Processing 498 ROIs from HT-AMP_xy15_056.zip
# Elapsed time: 41.900865 seconds.
# Compiling fluorescence from HT-AMP_xy15_056.txt
# Saving 498 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_056.pkl
#
# (Parallel) Processing 500 ROIs from HT-AMP_xy15_057.zip
# Elapsed time: 39.780954 seconds.
# Compiling fluorescence from HT-AMP_xy15_057.txt
# Saving 500 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_057.pkl
#
# (Parallel) Processing 514 ROIs from HT-AMP_xy15_058.zip
# Elapsed time: 43.644066 seconds.
# Compiling fluorescence from HT-AMP_xy15_058.txt
# Saving 514 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_058.pkl
#
# (Parallel) Processing 489 ROIs from HT-AMP_xy15_059.zip
# Elapsed time: 41.635676 seconds.
# Compiling fluorescence from HT-AMP_xy15_059.txt
# Saving 489 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_059.pkl
#
# (Parallel) Processing 487 ROIs from HT-AMP_xy15_060.zip
# Elapsed time: 45.999305 seconds.
# Compiling fluorescence from HT-AMP_xy15_060.txt
# Saving 487 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_060.pkl
#
# (Parallel) Processing 487 ROIs from HT-AMP_xy15_061.zip
# Elapsed time: 53.340383 seconds.
# Compiling fluorescence from HT-AMP_xy15_061.txt
# Saving 487 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_061.pkl
#
# (Parallel) Processing 502 ROIs from HT-AMP_xy15_062.zip
# Elapsed time: 51.666018 seconds.
# Compiling fluorescence from HT-AMP_xy15_062.txt
# Saving 502 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_062.pkl
#
# (Parallel) Processing 489 ROIs from HT-AMP_xy15_063.zip
# Elapsed time: 45.279183 seconds.
# Compiling fluorescence from HT-AMP_xy15_063.txt
# Saving 489 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_063.pkl
#
# (Parallel) Processing 481 ROIs from HT-AMP_xy15_064.zip
# Elapsed time: 52.005945 seconds.
# Compiling fluorescence from HT-AMP_xy15_064.txt
# Saving 481 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_064.pkl
#
# (Parallel) Processing 474 ROIs from HT-AMP_xy15_065.zip
# Elapsed time: 56.254286 seconds.
# Compiling fluorescence from HT-AMP_xy15_065.txt
# Saving 474 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_065.pkl
#
# (Parallel) Processing 485 ROIs from HT-AMP_xy15_066.zip
# Elapsed time: 64.291048 seconds.
# Compiling fluorescence from HT-AMP_xy15_066.txt
# Saving 485 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_066.pkl
#
# (Parallel) Processing 498 ROIs from HT-AMP_xy15_067.zip
# Elapsed time: 66.994766 seconds.
# Compiling fluorescence from HT-AMP_xy15_067.txt
# Saving 498 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_067.pkl
#
# (Parallel) Processing 480 ROIs from HT-AMP_xy15_068.zip
# Elapsed time: 80.276140 seconds.
# Compiling fluorescence from HT-AMP_xy15_068.txt
# Saving 480 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_068.pkl
#
# (Parallel) Processing 471 ROIs from HT-AMP_xy15_069.zip
# Elapsed time: 81.267904 seconds.
# Compiling fluorescence from HT-AMP_xy15_069.txt
# Saving 471 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_069.pkl
#
# (Parallel) Processing 473 ROIs from HT-AMP_xy15_070.zip
# Elapsed time: 63.350058 seconds.
# Compiling fluorescence from HT-AMP_xy15_070.txt
# Saving 473 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_070.pkl
#
# (Parallel) Processing 471 ROIs from HT-AMP_xy15_071.zip
# Elapsed time: 65.804530 seconds.
# Compiling fluorescence from HT-AMP_xy15_071.txt
# Saving 471 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_071.pkl
#
# (Parallel) Processing 471 ROIs from HT-AMP_xy15_072.zip
# Elapsed time: 73.032016 seconds.
# Compiling fluorescence from HT-AMP_xy15_072.txt
# Saving 471 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_072.pkl
#
# (Parallel) Processing 470 ROIs from HT-AMP_xy15_073.zip
# Elapsed time: 62.577176 seconds.
# Compiling fluorescence from HT-AMP_xy15_073.txt
# Saving 470 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_073.pkl
#
# (Parallel) Processing 445 ROIs from HT-AMP_xy15_074.zip
# Elapsed time: 74.208652 seconds.
# Compiling fluorescence from HT-AMP_xy15_074.txt
# Saving 445 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_074.pkl
#
# (Parallel) Processing 446 ROIs from HT-AMP_xy15_075.zip
# Elapsed time: 91.448811 seconds.
# Compiling fluorescence from HT-AMP_xy15_075.txt
# Saving 446 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_075.pkl
#
# (Parallel) Processing 456 ROIs from HT-AMP_xy15_076.zip
# Elapsed time: 117.498235 seconds.
# Compiling fluorescence from HT-AMP_xy15_076.txt
# Saving 456 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_076.pkl
#
# (Parallel) Processing 448 ROIs from HT-AMP_xy15_077.zip
# Elapsed time: 150.851527 seconds.
# Compiling fluorescence from HT-AMP_xy15_077.txt
# Saving 448 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_077.pkl
#
# (Parallel) Processing 432 ROIs from HT-AMP_xy15_078.zip
# Elapsed time: 169.775987 seconds.
# Compiling fluorescence from HT-AMP_xy15_078.txt
# Saving 432 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_078.pkl
#
# (Parallel) Processing 455 ROIs from HT-AMP_xy15_079.zip
# Elapsed time: 89.391240 seconds.
# Compiling fluorescence from HT-AMP_xy15_079.txt
# Saving 455 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_079.pkl
#
# (Parallel) Processing 469 ROIs from HT-AMP_xy15_080.zip
# Elapsed time: 47.573786 seconds.
# Compiling fluorescence from HT-AMP_xy15_080.txt
# Saving 469 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_080.pkl
#
# (Parallel) Processing 474 ROIs from HT-AMP_xy15_081.zip
# Elapsed time: 49.540838 seconds.
# Compiling fluorescence from HT-AMP_xy15_081.txt
# Saving 474 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_081.pkl
#
# (Parallel) Processing 467 ROIs from HT-AMP_xy15_082.zip
# Elapsed time: 53.340997 seconds.
# Compiling fluorescence from HT-AMP_xy15_082.txt
# Saving 467 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_082.pkl
#
# (Parallel) Processing 434 ROIs from HT-AMP_xy15_083.zip
# Elapsed time: 51.817369 seconds.
# Compiling fluorescence from HT-AMP_xy15_083.txt
# Saving 434 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_083.pkl
#
# (Parallel) Processing 441 ROIs from HT-AMP_xy15_084.zip
# Elapsed time: 51.350052 seconds.
# Compiling fluorescence from HT-AMP_xy15_084.txt
# Saving 441 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_084.pkl
#
# (Parallel) Processing 424 ROIs from HT-AMP_xy15_085.zip
# Elapsed time: 47.419421 seconds.
# Compiling fluorescence from HT-AMP_xy15_085.txt
# Saving 424 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_085.pkl
#
# (Parallel) Processing 428 ROIs from HT-AMP_xy15_086.zip
# Elapsed time: 43.159002 seconds.
# Compiling fluorescence from HT-AMP_xy15_086.txt
# Saving 428 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_086.pkl
#
# (Parallel) Processing 431 ROIs from HT-AMP_xy15_087.zip
# Elapsed time: 42.217645 seconds.
# Compiling fluorescence from HT-AMP_xy15_087.txt
# Saving 431 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_087.pkl
#
# (Parallel) Processing 426 ROIs from HT-AMP_xy15_088.zip
# Elapsed time: 45.564039 seconds.
# Compiling fluorescence from HT-AMP_xy15_088.txt
# Saving 426 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_088.pkl
#
# (Parallel) Processing 425 ROIs from HT-AMP_xy15_089.zip
# Elapsed time: 51.115277 seconds.
# Compiling fluorescence from HT-AMP_xy15_089.txt
# Saving 425 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_089.pkl
#
# (Parallel) Processing 420 ROIs from HT-AMP_xy15_090.zip
# Elapsed time: 50.740395 seconds.
# Compiling fluorescence from HT-AMP_xy15_090.txt
# Saving 420 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_090.pkl
#
# (Parallel) Processing 412 ROIs from HT-AMP_xy15_091.zip
# Elapsed time: 41.151169 seconds.
# Compiling fluorescence from HT-AMP_xy15_091.txt
# Saving 412 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_091.pkl
#
# (Parallel) Processing 441 ROIs from HT-AMP_xy15_092.zip
# Elapsed time: 48.981736 seconds.
# Compiling fluorescence from HT-AMP_xy15_092.txt
# Saving 441 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_092.pkl
#
# (Parallel) Processing 425 ROIs from HT-AMP_xy15_093.zip
# Elapsed time: 52.690706 seconds.
# Compiling fluorescence from HT-AMP_xy15_093.txt
# Saving 425 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_093.pkl
#
# (Parallel) Processing 414 ROIs from HT-AMP_xy15_094.zip
# Elapsed time: 42.435349 seconds.
# Compiling fluorescence from HT-AMP_xy15_094.txt
# Saving 414 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_094.pkl
#
# (Parallel) Processing 420 ROIs from HT-AMP_xy15_095.zip
# Elapsed time: 44.057903 seconds.
# Compiling fluorescence from HT-AMP_xy15_095.txt
# Saving 420 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_095.pkl
#
# (Parallel) Processing 398 ROIs from HT-AMP_xy15_096.zip
# Elapsed time: 48.976096 seconds.
# Compiling fluorescence from HT-AMP_xy15_096.txt
# Saving 398 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_096.pkl
#
# (Parallel) Processing 392 ROIs from HT-AMP_xy15_097.zip
# Elapsed time: 43.472540 seconds.
# Compiling fluorescence from HT-AMP_xy15_097.txt
# Saving 392 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_097.pkl
#
# (Parallel) Processing 401 ROIs from HT-AMP_xy15_098.zip
# Elapsed time: 45.303993 seconds.
# Compiling fluorescence from HT-AMP_xy15_098.txt
# Saving 401 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_098.pkl
#
# (Parallel) Processing 411 ROIs from HT-AMP_xy15_099.zip
# Elapsed time: 46.442623 seconds.
# Compiling fluorescence from HT-AMP_xy15_099.txt
# Saving 411 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_099.pkl
#
# (Parallel) Processing 395 ROIs from HT-AMP_xy15_100.zip
# Elapsed time: 60.439985 seconds.
# Compiling fluorescence from HT-AMP_xy15_100.txt
# Saving 395 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_100.pkl
#
# (Parallel) Processing 392 ROIs from HT-AMP_xy15_101.zip
# Elapsed time: 56.715095 seconds.
# Compiling fluorescence from HT-AMP_xy15_101.txt
# Saving 392 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_101.pkl
#
# (Parallel) Processing 374 ROIs from HT-AMP_xy15_102.zip
# Elapsed time: 56.276059 seconds.
# Compiling fluorescence from HT-AMP_xy15_102.txt
# Saving 374 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_102.pkl
#
# (Parallel) Processing 343 ROIs from HT-AMP_xy15_103.zip
# Elapsed time: 60.376225 seconds.
# Compiling fluorescence from HT-AMP_xy15_103.txt
# Saving 343 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_103.pkl
#
# (Parallel) Processing 356 ROIs from HT-AMP_xy15_104.zip
# Elapsed time: 86.242326 seconds.
# Compiling fluorescence from HT-AMP_xy15_104.txt
# Saving 356 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_104.pkl
#
# (Parallel) Processing 364 ROIs from HT-AMP_xy15_105.zip
# Elapsed time: 75.530853 seconds.
# Compiling fluorescence from HT-AMP_xy15_105.txt
# Saving 364 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_105.pkl
#
# (Parallel) Processing 370 ROIs from HT-AMP_xy15_106.zip
# Elapsed time: 89.935339 seconds.
# Compiling fluorescence from HT-AMP_xy15_106.txt
# Saving 370 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_106.pkl
#
# (Parallel) Processing 334 ROIs from HT-AMP_xy15_107.zip
# Elapsed time: 100.506339 seconds.
# Compiling fluorescence from HT-AMP_xy15_107.txt
# Saving 334 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_107.pkl
#
# (Parallel) Processing 337 ROIs from HT-AMP_xy15_108.zip
# Elapsed time: 123.236487 seconds.
# Compiling fluorescence from HT-AMP_xy15_108.txt
# Saving 337 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_108.pkl
#
# (Parallel) Processing 364 ROIs from HT-AMP_xy15_109.zip
# Elapsed time: 89.935827 seconds.
# Compiling fluorescence from HT-AMP_xy15_109.txt
# Saving 364 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_109.pkl
#
# (Parallel) Processing 359 ROIs from HT-AMP_xy15_110.zip
# Elapsed time: 100.299814 seconds.
# Compiling fluorescence from HT-AMP_xy15_110.txt
# Saving 359 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_110.pkl
#
# (Parallel) Processing 350 ROIs from HT-AMP_xy15_111.zip
# Elapsed time: 116.212651 seconds.
# Compiling fluorescence from HT-AMP_xy15_111.txt
# Saving 350 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_111.pkl
#
# (Parallel) Processing 345 ROIs from HT-AMP_xy15_112.zip
# Elapsed time: 113.060418 seconds.
# Compiling fluorescence from HT-AMP_xy15_112.txt
# Saving 345 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_112.pkl
#
# (Parallel) Processing 330 ROIs from HT-AMP_xy15_113.zip
# Elapsed time: 162.298837 seconds.
# Compiling fluorescence from HT-AMP_xy15_113.txt
# Saving 330 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_113.pkl
#
# (Parallel) Processing 329 ROIs from HT-AMP_xy15_114.zip
# Elapsed time: 233.285701 seconds.
# Compiling fluorescence from HT-AMP_xy15_114.txt
# Saving 329 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_114.pkl
#
# (Parallel) Processing 325 ROIs from HT-AMP_xy15_115.zip
# Elapsed time: 275.132190 seconds.
# Compiling fluorescence from HT-AMP_xy15_115.txt
# Saving 325 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_115.pkl
#
# (Parallel) Processing 326 ROIs from HT-AMP_xy15_116.zip
# Elapsed time: 189.773122 seconds.
# Compiling fluorescence from HT-AMP_xy15_116.txt
# Saving 326 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_116.pkl
#
# (Parallel) Processing 324 ROIs from HT-AMP_xy15_117.zip
# Elapsed time: 191.505129 seconds.
# Compiling fluorescence from HT-AMP_xy15_117.txt
# Saving 324 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_117.pkl
#
# (Parallel) Processing 313 ROIs from HT-AMP_xy15_118.zip
# Elapsed time: 240.049341 seconds.
# Compiling fluorescence from HT-AMP_xy15_118.txt
# Saving 313 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_118.pkl
#
# (Parallel) Processing 308 ROIs from HT-AMP_xy15_119.zip
# Elapsed time: 186.378017 seconds.
# Compiling fluorescence from HT-AMP_xy15_119.txt
# Saving 308 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_119.pkl
#
# (Parallel) Processing 305 ROIs from HT-AMP_xy15_120.zip
# Elapsed time: 291.336192 seconds.
# Compiling fluorescence from HT-AMP_xy15_120.txt
# Saving 305 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_120.pkl
#
# (Parallel) Processing 305 ROIs from HT-AMP_xy15_121.zip
# Elapsed time: 202.040223 seconds.
# Compiling fluorescence from HT-AMP_xy15_121.txt
# Saving 305 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_121.pkl
#
# (Parallel) Processing 286 ROIs from HT-AMP_xy15_122.zip
# Elapsed time: 200.578357 seconds.
# Compiling fluorescence from HT-AMP_xy15_122.txt
# Saving 286 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_122.pkl
#
# (Parallel) Processing 277 ROIs from HT-AMP_xy15_123.zip
# Elapsed time: 221.018714 seconds.
# Compiling fluorescence from HT-AMP_xy15_123.txt
# Saving 277 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_123.pkl
#
# (Parallel) Processing 284 ROIs from HT-AMP_xy15_124.zip
# Elapsed time: 195.622459 seconds.
# Compiling fluorescence from HT-AMP_xy15_124.txt
# Saving 284 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_124.pkl
#
# (Parallel) Processing 270 ROIs from HT-AMP_xy15_125.zip
# Elapsed time: 196.896986 seconds.
# Compiling fluorescence from HT-AMP_xy15_125.txt
# Saving 270 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_125.pkl
#
# (Parallel) Processing 263 ROIs from HT-AMP_xy15_126.zip
# Elapsed time: 189.552446 seconds.
# Compiling fluorescence from HT-AMP_xy15_126.txt
# Saving 263 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_126.pkl
#
# (Parallel) Processing 245 ROIs from HT-AMP_xy15_127.zip
# Elapsed time: 205.979030 seconds.
# Compiling fluorescence from HT-AMP_xy15_127.txt
# Saving 245 cells to ../../data_sample/HT-AMP/data_cells/xy15/normData/HT-AMP_xy15_127.pkl

# %% [markdown]
# ## View cells

# %%
# %matplotlib inline 

cells_plots_t=[]
cells=trap_cells[0]
for tracked_frame in range(len(cells)):
    this_fig=draw_cell(cells,tracked_frame+1)
    cells_plots_t.append(this_fig)

# %%
# %matplotlib inline 

this_tracked_plots=cells_plots_t
interactive_plot_t=interactive(show_all,this_tracked_plots=fixed(this_tracked_plots),tracked_frame=widgets.IntSlider(min=1,max=len(this_tracked_plots),step=1,value=1))
interactive_plot_t

# %% [markdown]
# ___
# # uJ_Tracker: Step 2

# %% [markdown]
# ### Select cells to track

# %%
# %matplotlib ipympl
#%matplotlib widgets

 #if plot does not show,uncomment this line run, comment and re-run
def onclickSelectMulti(event):

       #global max_frames

       #First find if Point is inside a roi
    this_point = Point(event.xdata,event.ydata)
    #if(event.y)
    
    title=event.inaxes.get_title()
    tindex=trap_list.index(title)
    to_track_polys=trap_to_track_polys[tindex]
    ax=axs[tindex]
    for select_index, select_poly in enumerate(to_track_polys):
        in_roi=select_poly.contains(this_point)
        if in_roi:
            select_x,select_y = select_poly.exterior.xy     
            ax.plot(select_x, select_y, color='#6699cc', alpha=0.7, linewidth=2, solid_capstyle='round', zorder=3)
            ax.axis('off')
            trap_toTrack_roiIndex[tindex].append(select_index)
            trap_toTrack_roiFrame[tindex].append(to_track_frame)
            #trap_toTrack_trapIndex
            
            break



fig,axs=plt.subplots(len(trap_cells),1,figsize=(30,30))
trap_to_track_polys=[]

trap_toTrack_roiIndex=[]
trap_toTrack_roiFrame=[]

for ti,t_cells in enumerate(trap_cells):
    cells=t_cells
    to_track_frame=len(cells)-1
    #to_track_frame=14
   # global toTrack_roiIndex
    trap_toTrack_roiIndex.append([])
    trap_toTrack_roiFrame.append([])




    
    #fig=plt.figure()
    ax = axs[ti]

    ax.set_xlim(0,640)
    ax.set_ylim(0,512)
    #ax.clear()
    to_track_polys=[]

    for this_cell in cells[to_track_frame]:
        this_poly=this_cell['roiPoly']
        to_track_polys.append(this_poly)
        patch = PolygonPatch(this_poly, facecolor=[0.75,0.75,0.75], edgecolor=[0,0,0], alpha=0.7, zorder=2)
        ax.add_patch(patch)
       #ax.plot(x=100,y=100,c='r*')
    #ax.axis('off')
    trap_to_track_polys.append(to_track_polys)
    ax.set_title(trap_list[ti])
    ax.set_aspect('equal')
    #fig.canvas.layout.width = '1280px'
    fig.canvas.layout.height = '%spx'%(512*len(trap_cells))
    fig.canvas.layout.width = '640px'
    #fig.canvas.layout.height = '512px'
    
    


cid = fig.canvas.mpl_connect('button_press_event', onclickSelectMulti)
#cid = plt.gcf().canvas.mpl_connect('button_press_event', onclickSelect)

# %%
#print(toTrack_roiIndex)
#print(toTrack_roiFrame)
weight_vec=[-5,-100,200,1500,-5,-5]
#weight_vec=[-1,-5,5,35,-175]
#[distance,angle_diff,coverage,axisFraction,GFPDiff,DsRedDiff]
trap_tracked_cells=[]
for ti,t_cells in enumerate(trap_cells):
    cells=t_cells
    cells=clear_tracks(cells)
    
    cells_tracked=cells.copy()
    if('cells_tracked' in vars()):
        cells_tracked=clear_tracks(cells_tracked)
    toTrack_roiIndex=trap_toTrack_roiIndex[ti]
    toTrack_roiFrame=trap_toTrack_roiFrame[ti]
    
    cells_tracked=track_this_indexs(toTrack_roiIndex,toTrack_roiFrame,cells,weight_vec) 
    
    trap_tracked_cells.append(cells_tracked)
    print('\n\nTracking complete! Trap:',trap)
    
    print("\nSaving cells...")
    file_cells= list(f for f in os.listdir(dirNameCELLS) if f.endswith('.pkl'))
    file_cells.sort()
    for frame, this_file in enumerate(file_cells):
        this_cells=cells_tracked[frame] 
        #print(frame, this_file)
        fileNameTrackedCells="%s%s.pkl"%(dirNameTRACKEDCELLS,os.path.splitext(os.path.basename(this_file))[0])    
    #    print(fileNameFrameCells)
        save_cells(this_cells, fileNameTrackedCells)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-eb82ee0a4051> in <module>()
#      12     if('cells_tracked' in vars()):
#      13         cells_tracked=clear_tracks(cells_tracked)
# ---> 14     toTrack_roiIndex=trap_toTrack_roiIndex[ti]
#      15     toTrack_roiFrame=trap_toTrack_roiFrame[ti]
#      16
#
# NameError: name 'trap_toTrack_roiIndex' is not defined

# %% [markdown]
# ### Track cells from last frame

# %%
#trap_list2=[trap_list[0]]
trap_tracked_cells=[]
for tindex,trap in enumerate(trap_list):

    dirNameCELLS=rootDir+'data_cells/'+trap+'/'+data_type+'/'
    dirNameTRACKEDCELLS=rootDir+'data_cells_tracked/'+trap+'/'+data_type+'/'
    
    
    cells=trap_cells[tindex]
    
    cells=clear_tracks(cells)
    cells_tracked=cells.copy()
    

    
    max_frames=len(cells)-1
    #max_frames=len(cells)-1

    from_frame=max_frames
    to_frame=max_frames-1
    
    for this_frame in range(from_frame,to_frame,-1):
        toTrack_roiIndex=[]
        toTrack_roiFrame=[]
        for select_index, this_cell in enumerate(cells_tracked[this_frame]):
            if len(this_cell['trackID'])==0:
                toTrack_roiFrame.append(this_frame)
                toTrack_roiIndex.append(select_index)
        print('\n___\nTracking %s cells from frame %s'%(len(toTrack_roiFrame),this_frame))
        cells_tracked=track_this_indexs(toTrack_roiIndex,toTrack_roiFrame,cells_tracked,weight_vec) 
    print('\n\nTracking complete! Trap:',trap)
    trap_tracked_cells.append(cells_tracked)
    print("\nSaving cells...")
    file_cells= list(f for f in os.listdir(dirNameCELLS) if f.endswith('.pkl'))
    file_cells.sort()
    for frame, this_file in enumerate(file_cells):
        this_cells=cells_tracked[frame] 
        #print(frame, this_file)
        fileNameTrackedCells="%s%s.pkl"%(dirNameTRACKEDCELLS,os.path.splitext(os.path.basename(this_file))[0])    
    #    print(fileNameFrameCells)
        save_cells(this_cells, fileNameTrackedCells)

# %% [markdown]
# ### Track all cells all frames

# %%
# Out:
# ['xy15', 'xy15-1']

# %%
weight_vec=[-5,-100,200,1500,-5,-5]

trap_tracked_cells=[]

for tindex,trap in enumerate(trap_list[0:1]):
    dirNameCELLS=rootDir+'data_cells/'+trap+'/'+data_type+'/'
    dirNameTRACKEDCELLS=rootDir+'data_cells_tracked/'+trap+'/'+data_type+'/'
    
    
    cells=trap_cells[tindex]
    
    cells=clear_tracks(cells)
    cells_tracked=cells.copy()
    
    max_frames=len(cells)-1
    from_frame=max_frames
    to_frame=0
    
    for this_frame in range(from_frame,to_frame,-1):
        toTrack_roiIndex=[]
        toTrack_roiFrame=[]
        for select_index, this_cell in enumerate(cells_tracked[this_frame]):
            if len(this_cell['trackID'])==0:
                toTrack_roiFrame.append(this_frame)
                toTrack_roiIndex.append(select_index)
        print('\n___\nTracking %s cells from frame %s'%(len(toTrack_roiFrame),this_frame))
        cells_tracked=track_this_indexs(toTrack_roiIndex,toTrack_roiFrame,cells_tracked,weight_vec) 
    print('\n\nTracking complete! Trap:',trap)
    trap_tracked_cells.append(cells_tracked)
    print("\nSaving cells...")
    file_cells= list(f for f in os.listdir(dirNameCELLS) if f.endswith('.pkl'))
    file_cells.sort()
    for frame, this_file in enumerate(file_cells):
        this_cells=cells_tracked[frame] 
        #print(frame, this_file)
        fileNameTrackedCells="%s%s.pkl"%(dirNameTRACKEDCELLS,os.path.splitext(os.path.basename(this_file))[0])    
    #    print(fileNameFrameCells)
        save_cells(this_cells, fileNameTrackedCells)
# Out:
# ___
# Tracking 245 cells from frame 72
#
# 0....................................................................................................
# 100....................................................................................................
# 200.............................................
# ___
# Tracking 54 cells from frame 71
#
# 0......................................................
# ___
# Tracking 68 cells from frame 70
#
# 0....................................................................
# ___
# Tracking 73 cells from frame 69
#
# 0.........................................................................
# ___
# Tracking 57 cells from frame 68
#
# 0.........................................................
# ___
# Tracking 59 cells from frame 67
#
# 0...........................................................
# ___
# Tracking 75 cells from frame 66
#
# 0...........................................................................
# ___
# Tracking 54 cells from frame 65
#
# 0......................................................
# ___
# Tracking 58 cells from frame 64
#
# 0..........................................................
# ___
# Tracking 62 cells from frame 63
#
# 0..............................................................
# ___
# Tracking 82 cells from frame 62
#
# 0..................................................................................
# ___
# Tracking 63 cells from frame 61
#
# 0...............................................................
# ___
# Tracking 65 cells from frame 60
#
# 0.................................................................
# ___
# Tracking 76 cells from frame 59
#
# 0............................................................................
# ___
# Tracking 68 cells from frame 58
#
# 0....................................................................
# ___
# Tracking 77 cells from frame 57
#
# 0.............................................................................
# ___
# Tracking 74 cells from frame 56
#
# 0..........................................................................
# ___
# Tracking 83 cells from frame 55
#
# 0...................................................................................
# ___
# Tracking 79 cells from frame 54
#
# 0...............................................................................
# ___
# Tracking 54 cells from frame 53
#
# 0......................................................
# ___
# Tracking 61 cells from frame 52
#
# 0.............................................................
# ___
# Tracking 91 cells from frame 51
#
# 0...........................................................................................
# ___
# Tracking 80 cells from frame 50
#
# 0................................................................................
# ___
# Tracking 75 cells from frame 49
#
# 0...........................................................................
# ___
# Tracking 66 cells from frame 48
#
# 0..................................................................
# ___
# Tracking 107 cells from frame 47
#
# 0....................................................................................................
# 100.......
# ___
# Tracking 87 cells from frame 46
#
# 0.......................................................................................
# ___
# Tracking 87 cells from frame 45
#
# 0.......................................................................................
# ___
# Tracking 80 cells from frame 44
#
# 0................................................................................
# ___
# Tracking 73 cells from frame 43
#
# 0.........................................................................
# ___
# Tracking 71 cells from frame 42
#
# 0.......................................................................
# ___
# Tracking 66 cells from frame 41
#
# 0..................................................................
# ___
# Tracking 74 cells from frame 40
#
# 0..........................................................................
# ___
# Tracking 69 cells from frame 39
#
# 0.....................................................................
# ___
# Tracking 83 cells from frame 38
#
# 0...................................................................................
# ___
# Tracking 88 cells from frame 37
#
# 0........................................................................................
# ___
# Tracking 58 cells from frame 36
#
# 0..........................................................
# ___
# Tracking 87 cells from frame 35
#
# 0.......................................................................................
# ___
# Tracking 82 cells from frame 34
#
# 0..................................................................................
# ___
# Tracking 70 cells from frame 33
#
# 0......................................................................
# ___
# Tracking 71 cells from frame 32
#
# 0.......................................................................
# ___
# Tracking 68 cells from frame 31
#
# 0....................................................................
# ___
# Tracking 82 cells from frame 30
#
# 0..................................................................................
# ___
# Tracking 90 cells from frame 29
#
# 0..........................................................................................
# ___
# Tracking 91 cells from frame 28
#
# 0...........................................................................................
# ___
# Tracking 108 cells from frame 27
#
# 0....................................................................................................
# 100........
# ___
# Tracking 77 cells from frame 26
#
# 0.............................................................................
# ___
# Tracking 77 cells from frame 25
#
# 0.............................................................................
# ___
# Tracking 82 cells from frame 24
#
# 0..................................................................................
# ___
# Tracking 71 cells from frame 23
#
# 0.......................................................................
# ___
# Tracking 79 cells from frame 22
#
# 0...............................................................................
# ___
# Tracking 82 cells from frame 21
#
# 0..................................................................................
# ___
# Tracking 71 cells from frame 20
#
# 0.......................................................................
# ___
# Tracking 74 cells from frame 19
#
# 0..........................................................................
# ___
# Tracking 94 cells from frame 18
#
# 0..............................................................................................
# ___
# Tracking 91 cells from frame 17
#
# 0...........................................................................................
# ___
# Tracking 79 cells from frame 16
#
# 0...............................................................................
# ___
# Tracking 73 cells from frame 15
#
# 0.........................................................................
# ___
# Tracking 72 cells from frame 14
#
# 0........................................................................
# ___
# Tracking 95 cells from frame 13
#
# 0...............................................................................................
# ___
# Tracking 92 cells from frame 12
#
# 0............................................................................................
# ___
# Tracking 83 cells from frame 11
#
# 0...................................................................................
# ___
# Tracking 86 cells from frame 10
#
# 0......................................................................................
# ___
# Tracking 94 cells from frame 9
#
# 0..............................................................................................
# ___
# Tracking 85 cells from frame 8
#
# 0.....................................................................................
# ___
# Tracking 96 cells from frame 7
#
# 0................................................................................................
# ___
# Tracking 96 cells from frame 6
#
# 0................................................................................................
# ___
# Tracking 84 cells from frame 5
#
# 0....................................................................................
# ___
# Tracking 73 cells from frame 4
# 0.........................................................................
# ___
# Tracking 100 cells from frame 3
#
# 0....................................................................................................
# ___
# Tracking 71 cells from frame 2
#
# 0.......................................................................
# ___
# Tracking 86 cells from frame 1
#
# 0......................................................................................
#
# Tracking complete! Trap: xy15
#
# Saving cells...
# Saving 503 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_055.pkl
# Saving 498 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_056.pkl
# Saving 500 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_057.pkl
# Saving 514 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_058.pkl
# Saving 489 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_059.pkl
# Saving 487 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_060.pkl
# Saving 487 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_061.pkl
# Saving 502 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_062.pkl
# Saving 489 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_063.pkl
# Saving 481 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_064.pkl
# Saving 474 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_065.pkl
# Saving 485 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_066.pkl
# Saving 498 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_067.pkl
# Saving 480 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_068.pkl
# Saving 471 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_069.pkl
# Saving 473 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_070.pkl
# Saving 471 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_071.pkl
# Saving 471 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_072.pkl
# Saving 470 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_073.pkl
# Saving 445 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_074.pkl
# Saving 446 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_075.pkl
# Saving 456 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_076.pkl
# Saving 448 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_077.pkl
# Saving 432 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_078.pkl
# Saving 455 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_079.pkl
# Saving 469 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_080.pkl
# Saving 474 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_081.pkl
# Saving 467 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_082.pkl
# Saving 434 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_083.pkl
# Saving 441 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_084.pkl
# Saving 424 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_085.pkl
# Saving 428 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_086.pkl
# Saving 431 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_087.pkl
# Saving 426 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_088.pkl
# Saving 425 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_089.pkl
# Saving 420 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_090.pkl
# Saving 412 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_091.pkl
# Saving 441 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_092.pkl
# Saving 425 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_093.pkl
# Saving 414 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_094.pkl
# Saving 420 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_095.pkl
# Saving 398 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_096.pkl
# Saving 392 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_097.pkl
# Saving 401 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_098.pkl
# Saving 411 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_099.pkl
# Saving 395 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_100.pkl
# Saving 392 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_101.pkl
# Saving 374 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_102.pkl
# Saving 343 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_103.pkl
# Saving 356 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_104.pkl
# Saving 364 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_105.pkl
# Saving 370 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_106.pkl
# Saving 334 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_107.pkl
# Saving 337 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_108.pkl
# Saving 364 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_109.pkl
# Saving 359 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_110.pkl
# Saving 350 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_111.pkl
# Saving 345 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_112.pkl
# Saving 330 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_113.pkl
# Saving 329 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_114.pkl
# Saving 325 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_115.pkl
# Saving 326 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_116.pkl
# Saving 324 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_117.pkl
# Saving 313 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_118.pkl
# Saving 308 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_119.pkl
# Saving 305 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_120.pkl
# Saving 305 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_121.pkl
# Saving 286 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_122.pkl
# Saving 277 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_123.pkl
# Saving 284 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_124.pkl
# Saving 270 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_125.pkl
# Saving 263 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_126.pkl
# Saving 245 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/HT-AMP_xy15_127.pkl

# %%
trap_list2=trap_list.copy()
trap_list2=["xy15-1"]
trap_cells2=trap_cells.copy()

#trap_tracked_cells=[]
for tindex,trap in enumerate(trap_list2):

    dirNameCELLS=rootDir+'data_cells/'+trap+'/'+data_type+'/'
    dirNameCELLS=rootDir+'data_cells/xy15/'+data_type+'/'
    dirNameTRACKEDCELLS=rootDir+'data_cells_tracked/'+trap+'/'+data_type+'/'
    print("Tracking trap: ",trap)
    
    cells=trap_cells2[tindex]
    
    cells=clear_tracks(cells)
    cells_tracked=cells.copy()
    

    
    max_frames=len(cells)-1
    #max_frames=len(cells)-1

    from_frame=max_frames
    to_frame=max_frames-1
    
    for this_frame in range(from_frame,to_frame,-1):
        toTrack_roiIndex=[]
        toTrack_roiFrame=[]
        for select_index, this_cell in enumerate(cells_tracked[this_frame]):
            if len(this_cell['trackID'])==0:
                toTrack_roiFrame.append(this_frame)
                toTrack_roiIndex.append(select_index)
        print('\n___\nTracking %s cells from frame %s'%(len(toTrack_roiFrame),this_frame))
        cells_tracked=track_this_indexs(toTrack_roiIndex,toTrack_roiFrame,cells_tracked,weight_vec) 
    print('\n\nTracking complete! Trap:',trap)
    trap_tracked_cells.append(cells_tracked)
    print("\nSaving cells...")
    file_cells= list(f for f in os.listdir(dirNameCELLS) if f.endswith('.pkl'))
    file_cells.sort()
    for frame, this_file in enumerate(file_cells):
        this_cells=cells_tracked[frame] 
        #print(frame, this_file)
        fileNameTrackedCells="%s%s.pkl"%(dirNameTRACKEDCELLS,os.path.splitext(os.path.basename(this_file))[0])    
    #    print(fileNameFrameCells)
        save_cells(this_cells, fileNameTrackedCells)
# Out:
# Tracking trap:  xy15-1
#
# ___
# Tracking 245 cells from frame 72
#
# 0....................................................................................................
# 100....................................................................................................
# 200.............................................
#
# Tracking complete! Trap: xy15-1
#
# Saving cells...
# Saving 503 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_055.pkl
# Saving 498 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_056.pkl
# Saving 500 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_057.pkl
# Saving 514 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_058.pkl
# Saving 489 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_059.pkl
# Saving 487 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_060.pkl
# Saving 487 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_061.pkl
# Saving 502 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_062.pkl
# Saving 489 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_063.pkl
# Saving 481 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_064.pkl
# Saving 474 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_065.pkl
# Saving 485 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_066.pkl
# Saving 498 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_067.pkl
# Saving 480 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_068.pkl
# Saving 471 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_069.pkl
# Saving 473 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_070.pkl
# Saving 471 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_071.pkl
# Saving 471 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_072.pkl
# Saving 470 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_073.pkl
# Saving 445 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_074.pkl
# Saving 446 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_075.pkl
# Saving 456 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_076.pkl
# Saving 448 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_077.pkl
# Saving 432 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_078.pkl
# Saving 455 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_079.pkl
# Saving 469 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_080.pkl
# Saving 474 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_081.pkl
# Saving 467 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_082.pkl
# Saving 434 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_083.pkl
# Saving 441 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_084.pkl
# Saving 424 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_085.pkl
# Saving 428 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_086.pkl
# Saving 431 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_087.pkl
# Saving 426 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_088.pkl
# Saving 425 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_089.pkl
# Saving 420 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_090.pkl
# Saving 412 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_091.pkl
# Saving 441 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_092.pkl
# Saving 425 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_093.pkl
# Saving 414 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_094.pkl
# Saving 420 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_095.pkl
# Saving 398 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_096.pkl
# Saving 392 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_097.pkl
# Saving 401 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_098.pkl
# Saving 411 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_099.pkl
# Saving 395 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_100.pkl
# Saving 392 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_101.pkl
# Saving 374 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_102.pkl
# Saving 343 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_103.pkl
# Saving 356 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_104.pkl
# Saving 364 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_105.pkl
# Saving 370 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_106.pkl
# Saving 334 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_107.pkl
# Saving 337 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_108.pkl
# Saving 364 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_109.pkl
# Saving 359 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_110.pkl
# Saving 350 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_111.pkl
# Saving 345 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_112.pkl
# Saving 330 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_113.pkl
# Saving 329 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_114.pkl
# Saving 325 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_115.pkl
# Saving 326 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_116.pkl
# Saving 324 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_117.pkl
# Saving 313 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_118.pkl
# Saving 308 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_119.pkl
# Saving 305 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_120.pkl
# Saving 305 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_121.pkl
# Saving 286 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_122.pkl
# Saving 277 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_123.pkl
# Saving 284 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_124.pkl
# Saving 270 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_125.pkl
# Saving 263 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_126.pkl
# Saving 245 cells to ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/HT-AMP_xy15_127.pkl

# %% [markdown]
# ### Load tracked cells

# %%
trap_tracked_cells=[]
for trap in trap_list:
    
    dirNameTRACKEDCELLS=rootDir+'data_cells_tracked/'+trap+'/'+data_type+'/'
    print(dirNameTRACKEDCELLS)
    tracked_cells=load_cells(dirNameTRACKEDCELLS)
    trap_tracked_cells.append(tracked_cells)
# Out:
# ../../data_sample/HT-AMP/data_cells_tracked/xy15/normData/
# 72: Loading HT-AMP_xy15_127.pkl
# ../../data_sample/HT-AMP/data_cells_tracked/xy15-1/normData/
# 72: Loading HT-AMP_xy15_127.pkl

# %% [markdown]
# ### Draw ROIs + Tracked Cells

# %%
# %matplotlib inline
#max_frames=len(cells_tracked)
trap_tracked_plots=[]
for tindex,trap in enumerate(trap_list):
    tracked_plots=[]
    cells_tracked=trap_tracked_cells[tindex]
    dirNameFIGURES=rootDir+'figures/traked_cells/'+trap+'/'+data_type+'/'
    print("Trap: %s in %s"%(trap,dirNameFIGURES))
    for i,tracked_frame in enumerate(frames_list):
        this_fig=draw_cell(cells_tracked,i+1,flims)
        #plt.show(this_fig)
        tracked_frame_name=str(tracked_frame).zfill(3)
        figname="%s%s_%s-%s.png"%(dirNameFIGURES,expeLabel,trap,tracked_frame_name)
        this_fig.savefig(figname)
        tracked_plots.append(this_fig)
       # display(this_fig)
        plt.close("all")
    print()
    trap_tracked_plots.append(tracked_plots)
# Out:
# Trap: xy15 in ../../data_sample/HT-AMP/figures/traked_cells/xy15/normData/
# Building plot for frame frame 73
# Trap: xy15-1 in ../../data_sample/HT-AMP/figures/traked_cells/xy15-1/normData/
# Building plot for frame frame 73

# %%
this_tracked_plots=trap_tracked_plots[0]
#interactive_plot=interactive(show_all,this_tracked_plots=fixed(this_tracked_plots),tracked_frame=widgets.IntSlider(min=1,max=max_frames,step=1,value=1),fs=fixed(frame_experiment_start))
interactive_plot=interactive(show_all,this_tracked_plots=fixed(this_tracked_plots),tracked_frame=widgets.IntSlider(min=frame_experiment_start,max=frame_experiment_end,step=1,value=1),fs=fixed(frame_experiment_start))
interactive_plot
# Out:
# interactive(children=(IntSlider(value=55, description='tracked_frame', max=127, min=55), Output()), _dom_class…

# %%
this_tracked_plots=trap_tracked_plots[1]
#interactive_plot=interactive(show_all,this_tracked_plots=fixed(this_tracked_plots),tracked_frame=widgets.IntSlider(min=1,max=max_frames,step=1,value=1),fs=fixed(frame_experiment_start))
interactive_plot=interactive(show_all,this_tracked_plots=fixed(this_tracked_plots),tracked_frame=widgets.IntSlider(min=frame_experiment_start,max=frame_experiment_end,step=1,value=1),fs=fixed(frame_experiment_start))
interactive_plot
# Out:
# interactive(children=(IntSlider(value=55, description='tracked_frame', max=127, min=55), Output()), _dom_class…

# %%
# %%html
# <style>
# .output_wrapper button.btn.btn-default,
# .output_wrapper .ui-dialog-titlebar {
#  display: none;
# }
# </style>
